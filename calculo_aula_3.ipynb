# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/calculo_aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritmos
# - Cálculo da área
#
#  # Entrada
#  - Ler lado1
#  - Ler lado2
#
#  # Processamento
#  área= lado1 * lado2
#
#  # Saída
#  imprimir área

# %%
# Calculo da área

# Entrada

lado1 = 5

lado2 = 4


nome = "Mell"

# %%
print (Mell)

# %%
# Processamento

área = lado1 * lado2

# %%
# Saída

print (f"Total da área: {área}")
# Out:
# Total da área: 20

# %%
# Tipos Numéricos
idade = 14  # int

altura = 1.54  # float

numero_complexo = 2 + 3j  # complex

# Tipo Texto
nome = "Marina" # str

#tipo booleano
está_chovendo = False #boot

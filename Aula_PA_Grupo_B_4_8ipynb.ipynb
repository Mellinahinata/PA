# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/Aula_PA_Grupo_B_4_8ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 - criando variáveis

nome = "alissa"
idade = 17
altura = 1,69
nota = 7
cidade = "Sumaré"
print(type(nome))
print(type(idade))
print(type(altura))
print(type(nota))
print(type(cidade))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'tuple'>
# <class 'int'>
# <class 'str'>

# %%
# Exercício 2 – Contas básicas
# Escreva um programa que:
# • Guarde as notas 7.5, 8.0 e 6.5
# • Calcule a média
# • Mostre a média na tela
nota1 = 7.5
nota2 = 8.0
nota3 = 6.5
media = (nota1 + nota2 + nota3) / 3

print(media)
# Out:
# 7.333333333333333

# %%
# Exercício 3 – Conversões
# Faça as conversões e mostre o resultado:
# texto1 = "20"
# texto2 = "3.5"
# numero = 8
# a) Transforme texto1 em inteiro e some com 10
# b) Transforme texto2 em real e multiplique por 2
# c) Transforme número em texto e junte com a palavra "anos"
texto1 = "20"
texto2 = "3.5"
numero = 8
print(int(texto1) + 10)
print(float(texto2) * 2 )
print(str(numero) + " anos")
# Out:
# 30
# 7.0
# 8 anos

# %%
# Exercício 4 – Expressões aritméticas
# Calcule e mostre o resultado de:
# • O dobro de 15
# • A metade de 90
# • O resto da divisão de 17 por 5
# • 2 elevados à potência 4
# • A média de 10, 8 e 6

valor1 = 15
dobro = print(valor1 * 2)

valor2 = 90
metade = print(valor2 / 2)

valor3 = 17
resto = print(valor3 % 5)

valor4 = 2
potencia = print(valor4 ** 4)

media = print((10 + 8 + 6) / 3)
# Out:
# 30
# 45.0
# 2
# 16
# 8.0

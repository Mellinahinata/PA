# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/exerc%C3%ADcios_listas_e_tupla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **listas**

# %%
#1
frutas = ["maçã","banana","laranja","morango"]
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
#2
nomes = ("Rebeca","Guilherme","Melissa","Kyara")
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
#3
cores = ["vermelho","azul","verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
#4
alunos = ["Nicolas","Wendel","Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
#5
animais = ["cachorro","gato","coelho","passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# # **tuplas**

# %%
#1
meses = ("janeiro","fevereiro","março","abril")
print(meses)
# Out:
# ('janeiro', 'fevereiro', 'março', 'abril')

# %%
#2
numeros = (10,20,30,40,50)
print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %%
#3
aluno = ("Aria",16,"Quimíca")
print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Aria
# 16
# Quimíca

# %%
#4
cores = ("vermelho","azul","verde")
cores[1] = "amarelo"
print(cores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1300/45769365.py in <cell line: 0>()
#       1 #4
#       2 cores = ("vermelho","azul","verde")
# ----> 3 cores[1] = "amarelo"
#       4 print(cores)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# -> Ocorre um erro devido a tupla ser imutável.

# %%
#5
numeros = (2,4,2,6,2,8,10)
quantidadedois = numeros.count(2)
print(quantidadedois)
# Out:
# 3

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/Aula_PA_22_09_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DICIONÁRIO
aluno  = {
    "nome": "Ana",
    "idade": 17,
    "curso": "informática"
}

aluno["idade"] = 18
aluno["cidade"]  = "Mauá"
print(aluno)
# Out:
# {'nome': 'Ana', 'idade': 18, 'curso': 'informática', 'cidade': 'Mauá'}

# %%
# conjuntos
numeros = {1, 2, 2, 3, 3, 4}
numeros.add(5)
numeros.remove(2)
print(numeros)
# Out:
# {1, 3, 4, 5}

# %% [markdown]
# ***EXERCÍCIOS DE DICIONÁRIO***

# %%
#1
aluno  = {
    "nome": "Adela",
    "idade": 15,
    "curso": "nutrição"
}

print(aluno)
# Out:
# {'nome': 'Adela', 'idade': 15, 'curso': 'nutrição'}

# %%
# 2
aluno  = {
    "nome": "Ivan",
    "idade": 18,
    "curso": "administração"
}

print(aluno["nome"])
print      (aluno["idade"])
print      (aluno["curso"])
# Out:
# Ivan
# 18
# administração

# %%
# 3
produto  = {
    "nome": "Teclado mecânico",
    "preço": 120.00,
    "estoque": 15
}

print(produto)
produto["estoque"] = 10
print(produto)
# Out:
# {'nome': 'Teclado mecânico', 'preço': 120.0, 'estoque': 15}
# {'nome': 'Teclado mecânico', 'preço': 120.0, 'estoque': 10}

# %%
# 4
aluno  = {
    "nome": "Alice",
    "idade": 16
}

print(aluno)
aluno["curso"] = "informática"
print(aluno)
# Out:
# {'nome': 'Alice', 'idade': 16}
# {'nome': 'Alice', 'idade': 16, 'curso': 'informática'}

# %%
# 5
filme = {
    "título": "Histórias Cruzadas",
    "ano": 2011,
    "gênero": "drama",
    "nota": 8.5
}
print(filme["título"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Histórias Cruzadas
# 2011
# drama
# 8.5

# %% [markdown]
# ***EXERCÍCIOS CONJUNTOS***

# %%
# 1
conjunto = {1, 2, 3, 4, 5}
print(conjunto)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 2
numeros = {1, 2, 2, 3, 3, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# -> os números repetidos somem

# %%
# 3
frutas = {"maçã", "banana", "laranja"}
frutas.add("morango")
print(frutas)
# Out:
# {'morango', 'laranja', 'banana', 'maçã'}

# %%
# 4
cores = {"vermelho", "azul", "verde", "amarelo"}
cores.remove("verde")
print(cores)
# Out:
# {'azul', 'amarelo', 'vermelho'}

# %%
# 5
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi",
"Gael","Theo", "Theo"]
# Transforme a lista em um conjunto para eliminar os nomes repetidos.
nomes = {"Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi",
"Gael","Theo", "Theo"}
print (nomes)
# Out:
# {'Gael', 'Ravi', 'Maitê', 'Luna', 'Theo', 'Yris'}

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/Aula_PA_25_03_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Decisões

a = int (input ("digitar um número:  "))
b = int (input ("digitar um número:  "))

if a > b:

  print (f"{a} é maior que {b}")

else:

  print (f"{b} é maior que {a}. ")
# Out:
# digitar um número:  41
# digitar um número:  98
# 98 é maior que 41.

# %%
# Escrever um programa que recebe 04 notas do aluno, calcula a média e mostra se o aluno foi aprovado.


# Entrada
print ("digite suas notas aqui, valores de 01 a 10!")
nota1 = float (input ("digite a nota do 1º bimestre:  "))
nota2 = float (input ("digite a nota do 2º bimestre:  "))
nota3 = float (input ("digite a nota do 3º bimestre:  "))
nota4 = float (input ("digite a nota do 4º bimestre:  "))

# processamento

resultado = (nota1 + nota2 + nota3 + nota4) / 4

if resultado >= 7:
  print (f"A média das suas notas foi {resultado}, vocÊ foi aprovado.")

elif resultado >= 5:

  print (f"A média das suas notas foi {resultado}, você terá que fazer recuperação.")

else:

  print(f"A média da suas notas foi {resultado}, você foi reprovado.")
# Out:
# digite suas notas aqui, valores de 01 a 10!
# digite a nota do 1º bimestre:  7
# digite a nota do 2º bimestre:  6
# digite a nota do 3º bimestre:  8
# digite a nota do 4º bimestre:  7
# A média das suas notas foi 7.0, vocÊ foi aprovado.

# %%
# Fazer uma calculadora simples com as 04 operações


print("----------------MENU-----------------")
print("")
print (" Opção 1 = SOMA")
print (" Opção 2 = SUBTRAÇÃO")
print (" Opção 3 = MULTIPLICAÇÃO")
print ( " Opção 4 = DIVISÃO")
print("")

opcao = int (input("digite a opção:  "))

# Entrada
a = float (input("digite o primeiro número:  "))
b = float (input("digite o segundo número:  "))
opcao1 = a + b
opcao2 = a - b
opcao3 = a * b
opcao4 = a /b

# Processamento
if opcao < 1 or opcao > 4:
  print(f" Digite uma opção válida!")
  print ("")

  opcao = int (input ("digite sua opção:  "))

  a = float (input("digite um número:"))
  b = float (input("digite um número:"))

if opcao == 1:
  print ("--------------SOMA--------------")
  print ("")
  print(f"A soma de {a} e {b} é igual a : {a + b}")
elif opcao == 2:
  print ("")
  print ("--------------SUBTRAÇÃO--------------")
  print ("")
  print(f"A subtração de {a} e {b} é igual a : {a - b}")
elif opcao == 3:
  print("")
  print("--------------MULTIPLICAÇÃO--------------")
  print ("")
  print(f"A multiplicação de {a} e {b} é igual a : {a * b}")
elif opcao == 4:
    print("")
    print("--------------DIVISÃO--------------")
    print ("")
    print("Erro: Divisão por zero não é permitida.")
    print(f"A divisao de {a} e {b} é igual a : {a / b}")
# Out:
# ----------------MENU-----------------
#
#  Opção 1 = SOMA
#  Opção 2 = SUBTRAÇÃO
#  Opção 3 = MULTIPLICAÇÃO
#  Opção 4 = DIVISÃO
#
# digite a opção:  3
# digite o primeiro número:  4
# digite o segundo número:  5
#
# --------------MULTIPLICAÇÃO--------------
#
# A multiplicação de 4.0 e 5.0 é igual a : 20.0

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mellinahinata/PA/blob/main/olamundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("olá mundo")
# Out:
# olá mundo
